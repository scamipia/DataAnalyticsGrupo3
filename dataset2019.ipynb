# %%
import pandas as pd

# %%
#ds = pd.read_csv('Crime_Data_from_2010_to_2019.csv')

# %%
df = ds.drop(['Mocodes', 'Part 1-2', 'Crm Cd 1','Crm Cd 2','Crm Cd 3','Crm Cd 4'], axis=1)

# %%
df[df['Premis Cd']== 256.0]['Premis Desc'].value_counts(ascending=False)
# Out:
# Series([], Name: count, dtype: int64)

# %%
df[df['Premis Cd']== 418.0]
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 1686767  180126492  10/19/2018 12:00:00 AM  10/03/2018 12:00:00 AM       235
# 1701466  181911543  05/24/2018 12:00:00 AM  05/24/2018 12:00:00 AM       535
# 1701948  180300555  02/17/2018 12:00:00 AM  02/17/2018 12:00:00 AM      2225
# 1706049  181208578  03/01/2018 12:00:00 AM  02/27/2018 12:00:00 AM      1700
# 1709059  180129081  11/28/2018 12:00:00 AM  11/28/2018 12:00:00 AM      1110
# ...            ...                     ...                     ...       ...
# 2110368  190906676  02/23/2019 12:00:00 AM  02/23/2019 12:00:00 AM       945
# 2110416  190707087  03/04/2019 12:00:00 AM  01/24/2019 12:00:00 AM       300
# 2116887  191227224  11/19/2019 12:00:00 AM  11/19/2019 12:00:00 AM      2240
# 2116926  190223459  12/17/2019 12:00:00 AM  12/15/2019 12:00:00 AM      2145
# 2122407  190616877  08/07/2019 12:00:00 AM  08/07/2019 12:00:00 AM       314
#
# ...
